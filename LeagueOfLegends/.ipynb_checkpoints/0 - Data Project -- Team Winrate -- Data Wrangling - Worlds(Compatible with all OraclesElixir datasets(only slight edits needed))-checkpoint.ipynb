# %%
#general imports
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import graphviz
# %matplotlib inline

# %%
alldata = pd.read_csv(r"C:\Users\Triplea657\000 MSCS-335 2020\Datasets\2019-summer-OraclesElixir.csv")
# Out:
# C:\Users\Triplea657\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(alldata.head())
alldata.count(axis=0)[0]
# Out:
#     gameid                                                url league   split  \
# 0  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 1  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 2  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 3  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 4  1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
#
#           date week game  patchno  playerid  side  ... gdat15  xpat10  \
# 0  43617.64992    1    1      9.1         1  Blue  ... -668.0  4453.0
# 1  43617.64992    1    1      9.1         2  Blue  ...  546.0  3876.0
# 2  43617.64992    1    1      9.1         3  Blue  ...  402.0  4973.0
# 3  43617.64992    1    1      9.1         4  Blue  ...  406.0  3275.0
# 4  43617.64992    1    1      9.1         5  Blue  ...  -15.0  2683.0
#
#   oppxpat10 xpdat10 csat10 oppcsat10 csdat10 csat15 oppcsat15  csdat15
# ...

# %%
'''
inddata = alldata.copy()
#del alldata
for i in range(int((inddata.count(axis=0)[0])/12)):#drop non-player rows
    inddata = inddata.drop([12*(i+1)-2,12*(i+1)-1])
inddata.reindex
print(inddata.head(15))
inddata.tail(21)
'''
# Out:
#      gameid                                                url league   split  \
# 0   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 1   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 2   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 3   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 4   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 5   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 6   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 7   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 8   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 9   1092338  http://matchhistory.na.leagueoflegends.com/en/...    LCS  2019-2
# 12  1092362  https://matchhistory.na.leagueoflegends.com/en...    LCS  2019-2
# ...

# %%
var = []
for i in inddata:
    var.append(i)
print(var)
for i, v in enumerate(var):
    print(i, v)
# Out:
# ['gameid', 'url', 'league', 'split', 'date', 'week', 'game', 'patchno', 'playerid', 'side', 'position', 'player', 'team', 'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'gamelength', 'result', 'k', 'd', 'a', 'teamkills', 'teamdeaths', 'doubles', 'triples', 'quadras', 'pentas', 'fb', 'fbassist', 'fbvictim', 'fbtime', 'kpm', 'okpm', 'ckpm', 'fd', 'fdtime', 'teamdragkills', 'oppdragkills', 'elementals', 'oppelementals', 'firedrakes', 'waterdrakes', 'earthdrakes', 'airdrakes', 'elders', 'oppelders', 'herald', 'heraldtime', 'ft', 'fttime', 'firstmidouter', 'firsttothreetowers', 'teamtowerkills', 'opptowerkills', 'fbaron', 'fbarontime', 'teambaronkills', 'oppbaronkills', 'dmgtochamps', 'dmgtochampsperminute', 'dmgshare', 'earnedgoldshare', 'wards', 'wpm', 'wardshare', 'wardkills', 'wcpm', 'visionwards', 'visionwardbuys', 'visiblewardclearrate', 'invisiblewardclearrate', 'totalgold', 'earnedgpm', 'goldspent', 'gspd', 'minionkills', 'monsterkills', 'monsterkillsownjungle', 'monsterkills
# ...

# %%
data = inddata.copy()
#del inddata

todrop = [var[1],var[3],var[4],var[5],var[7],var[14],var[15],var[16],var[17],var[18]]
print("dropping:{}".format(todrop))
data = data.drop(todrop,axis=1)
data.head()
# Out:
# dropping:['url', ['split', 'date', 'week'], 'patchno', ['ban1', 'ban2', 'ban3', 'ban4', 'ban5']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-289031e2f722> in <module>
#       4 todrop = [var[1],var[3:6],var[7],var[14:19]]
#       5 print("dropping:{}".format(todrop))
# ----> 6 data = data.drop(todrop,axis=1)
#       7 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...
